# %% [markdown]
# # PHY482 Group Project
# Authors: **Kyle Taft and Thong Van**

# %% [markdown]
# # Abstract
#
# Our code and computation will initially focus on a monochromatic plane wave interacting with different components essential to manipulating light via amplitude, phase, and polarization. We first explore the simple cases of the half and quarter wave plate. Next, we describe how our light wave changes with respect to an electro-optic modulator (EOM) or a voltage controlled birefringent crystal. We will compute consequences from such interactions such as sidebands and identify interesting scenarios at extremes of our set parameters(frequency, voltage, index of refraction, materials, etc).
#
# We then decipher how our light wave changes with respect to a basic SLM unit cell in the following respective order: cover glass, birefringent crystal, mirror coating. We combine our basic SLM cell with other optical approaches such as a wave plate or even a Machl-Zehnder interferometer to design an architecture capable of creating bright, mild, and dark spots by interference. Finally, we compute how to create different kinds of patterns or even images by controlling contrast between brightness and maybe even colors. If time permits, we will compute the voltages and polarization of different incident light waves needed to create an image

# %% [markdown]
# # Code Setup

# %%
# Import packages
import numpy as np
import matplotlib.pyplot as plt
import imageio
import os
import shutil
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
# Define constants
# c = 299792458  # Speed of light (m/s)
c = 1 
k = 4  # Wavenumber (rad/m)
w = k * c  # Angular frequency (rad/s)
E0 = 1  # Amplitude of electric field (V/m)
B0 = E0 / c  # Amplitude of magnetic field (T)

# Define the time parameters
tmax = 10
delta_t = 0.1

# Choose a propagation direction 
prop_dir = np.array([1, 0, 0])

# Choose a polarization direction
pol_dir = np.array([0, 1, 0])

# %%
# Define fundamental functions
def electric_field(x, y, z, t=0, prop_dir=np.array([1, 0, 0]), pol_dir=np.array([0, 1, 0]),n=1):
    """
    Calculate the electric field at a given point in space and time
    :param x,y,z: spacial coordinate of the point
    :param t: time
    :param prop_dir: propagation direction of the wave
    :param pol_dir: polarization direction of the electric field
    :param index: index specifying the direction
    :param n: refractive index
    :return: Ex, Ey, Ez: electric field components at the given point and time
    """
    # Calculate k and phase velocity from n

    v = c/n
    k= w/v
    
    # Define the electric field equation
    E = E0 * np.exp(1j * (k * (prop_dir[0] * x + prop_dir[1] * y + prop_dir[2] * z) - w * t))

    # Calculate electric field components
    Ex = E.real * pol_dir[0]
    Ey = (E * pol_dir[1]).real
    Ez = (E * pol_dir[2]).real
    return Ex, Ey, Ez

def magnetic_field(x, y, z, t=0, prop_dir=np.array([1, 0, 0]), pol_dir=np.array([0, 1, 0])):
    """
    Calculate the magnetic field at a given point in space and time
    :param x,y,z: spacial coordinate of the point
    :param t: time
    :param prop_dir: propagation direction of the wave
    :param pol_dir: polarization direction of the electric field
    :param index: index specifying the direction
    :return: Bx, By, Bz: magnetic field components at the given point and time
    """
    # Find the direction of the magnetic field
    B_direction = np.cross(prop_dir, pol_dir)

    # Calculate the magnetic field
    B = B0 * np.exp(1j * (k * (prop_dir[0] * x + prop_dir[1] * y + prop_dir[2] * z) - w * t))

    # Calculate magnetic field components
    Bx = B.real * B_direction[0]
    By = B.real * B_direction[1]
    Bz = B.real * B_direction[2]
    return Bx, By, Bz

def max_coordinate(prop_dir, t, index):
    """
    Define how far the wave has propagated in the given direction
    :param prop_dir: propagation direction of the wave
    :param t: time
    :param index: index specifying the direction
    :return: maximum coordinate in the given direction
    """
    if prop_dir[index] == 0:
        return 1
    else:
        return prop_dir[index] * c * t

# %% [markdown]
# # Monochromatic wave

# %%
# Mono-chromatic wave

def simple_wave(save_as):
	for i, t in enumerate(np.arange(0, tmax, delta_t)):
		fig = plt.figure()
		ax = fig.add_subplot(111, projection='3d')
		
		# Define grid for plotting
		num_points = 100
		x = np.linspace(0, max_coordinate(prop_dir, tmax, 0), num_points)
		y = np.linspace(0, max_coordinate(prop_dir, tmax, 1), num_points)
		z = np.linspace(0, max_coordinate(prop_dir, tmax, 2), num_points)

		# Calculate the field components
		Ex, Ey, Ez = electric_field(x, y, z, t=t, prop_dir=prop_dir, pol_dir=pol_dir)
		Bx, By, Bz = magnetic_field(x, y, z, t=t, prop_dir=prop_dir, pol_dir=pol_dir)

		# Plot in 3D
		ax.plot(x, Ey, Ez, color='b', label='Electric field')
		ax.plot(x, By, Bz, color='r', label='Magnetic field')

		# Show the propagation direction
		ax.plot([0, prop_dir[0] * max_coordinate(prop_dir, tmax, 0)], 
				[0, prop_dir[1] * max_coordinate(prop_dir, tmax, 1)], 
				[0, prop_dir[2] * max_coordinate(prop_dir, tmax, 2)], color='k', linestyle='--', label='Propagation axis')

		ax.set_xlim(-1, max_coordinate(prop_dir, 10, 0))
		ax.set_ylim(-1, max_coordinate(prop_dir, 10, 1))
		ax.set_zlim(-1, max_coordinate(prop_dir, 10, 2))
		ax.set_box_aspect([3, 1, 1])
		# Set the labels and title
		ax.set_xlabel('X')
		ax.set_ylabel('Y')
		ax.set_zlabel('Z')
		ax.set_title('Mono-chromatic plane wave in 3D')
		ax.legend()
		ax.figure.savefig(f'figures/{save_as}_{i:02d}.png')
		plt.close()

# %% [markdown]
# # Half-wave plate and Quarter-wave plate
#
# A waveplate is characterized by the difference in phase it introduces to an incident wave given by $ \Gamma = \frac{2 \pi \Delta n L}{\lambda _0}$. Here, $\Delta n$ is the difference of refractive index between the fast and slow axis of the birefringent crystal, $L$ is the crystals thickness, and $\lambda _0$ is the wavelength of the incident light in a vacuum. For the following demonstration, we place a waveplate at the $x=5$ plane represented by the green surface. Furthermore, we let the propagation of our light be normal to our waveplate and only show the electric field so that it is easier to see the change in polarization.

# %%
# Waveplate

def waveplate(deltan, lambda0, L, platetype, save_as, plate=5):
    """
    Generate a representation of a wave interacting with a waveplate
    :param deltan: difference of refractive index between fast and slow axis
    :param lambda0: wavelength of the light wave in a vacuum
    :param L: Length of the waveplate
    :param save_as: Base name of saved images
    :param plate: location of the plate along the x-axis
    """
    def gamma(deltan, lambda0, L):
        """
        Determine gamma (phase shift) as shown in the equation above
        :param deltan: difference of refractive index between fast and slow axis
        :param lambda0: wavelength of the light wave in a vacuum
        :param L: Length of the waveplate
        :return: gamma or the change of polarization
        """
        return 2*np.pi*deltan*L / lambda0
    
    phase = gamma(deltan, lambda0, L)

    # Decide whether to include a half or quarter waveplate
    if platetype == 'half':
        pol_dir2 = np.array([0,np.cos(phase),np.sin(phase)])
    elif platetype == 'quarter':
        pol_dir2 = np.array([0, 1 , np.exp(1j*phase)])
        
    for i, t in enumerate(np.arange(0, tmax, delta_t)):
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        
        # Define grid for plotting
        num_points = 50
        
        x = np.linspace(0, plate, num_points)
        y = np.linspace(0, max_coordinate(prop_dir, tmax, 1), num_points)
        z = np.linspace(0, max_coordinate(prop_dir, tmax, 2), num_points)

        
        x2 = np.linspace(plate, max_coordinate(prop_dir, tmax, 0), num_points)
        y2 = np.linspace(plate, max_coordinate(prop_dir, tmax, 1), num_points)
        z2 = np.linspace(plate, max_coordinate(prop_dir, tmax, 2), num_points)

        # Calculate the field components
        Ex, Ey, Ez = electric_field(x, y, z, t=t, prop_dir=prop_dir, pol_dir=pol_dir)
        # Calculate the field components after waveplate
        Ex2, Ey2, Ez2 = electric_field(x, y, z, t=t, prop_dir=prop_dir, pol_dir=pol_dir2)

        
        # Plot in 3D
        ax.plot(x, Ey, Ez, color='b', label='Electric field')
    
        # Show the propagation direction
        ax.plot([0, prop_dir[0] * max_coordinate(prop_dir, tmax, 0)], 
                [0, prop_dir[1] * max_coordinate(prop_dir, tmax, 1)], 
                [0, prop_dir[2] * max_coordinate(prop_dir, tmax, 2)], color='k', linestyle='--', label='Propagation axis')

        ax.plot(x2, Ey2.real, Ez2.real, color='b')
    
        ax.set_xlim(0, max_coordinate(prop_dir, 10, 0))
        ax.set_ylim(-1, max_coordinate(prop_dir, 10, 1))
        ax.set_zlim(-1, max_coordinate(prop_dir, 10, 2))

        x_start = plate
        y_limits = [-1, max_coordinate(prop_dir, 10, 1)]
        z_limits = [-1, max_coordinate(prop_dir, 10, 2)]
        vertices = [(x_start, y_limits[0], z_limits[0]),
            (x_start, y_limits[0], z_limits[1]),
            (x_start, y_limits[1], z_limits[1]),
            (x_start, y_limits[1], z_limits[0])]
        verts = [vertices]

        ax.view_init(15, 45)
        
        ax.add_collection3d(Poly3DCollection(verts, alpha=0.3, facecolor='g'))
        ax.set_box_aspect([3, 1, 1])
        # Set the labels and title
        ax.set_xlabel('X')
        ax.set_ylabel('Y')
        ax.set_zlabel('Z')
        ax.set_title('Mono-chromatic plane wave in 3D')
        ax.legend()
        #plt.show()
        ax.figure.savefig(f'figures/{save_as}_{i:02d}.png')
        plt.close()

# %%
## Save the collection of images produced from the function.
deltan = .5*(1/6) # Difference between refractive indices of the wave plate
L = 5e-7 # Length of the waveplate itself [m]
lambda0 = 5e-7 # Wavelength of the light in vacuum [m]
plate_type = 'half' # Choose 'quarter' or 'half' for the type of waveplate

# Clear output directory
if os.path.exists('figures'):
    shutil.rmtree('figures')
os.makedirs('figures')
     

image_name = f'{plate_type}_phase_30' # Base name for images
waveplate(deltan, L, lambda0, plate_type, image_name) # Produce set of images for wave

# image_name = 'simple_wave'
# simple_wave(image_name) # Produce set of images for wave


### Create a GIF from the images

# Get list of input PNG files
png_files = sorted([os.path.join('figures', file) for file in os.listdir('figures') if file.endswith('.png')])

# Read PNG images and create GIF
with imageio.get_writer(image_name+'.gif', mode='I', duration=0.2) as writer:
    for png_file in png_files:
        image = imageio.imread(png_file)
        writer.append_data(image)

# %% [markdown]
# # Electric Optic Modulator (EOM)
#
# Suppose there is a linear relationship between the voltage applied for the crystal in our EOM, then we have $\Delta n = r * V$ where n is the refractive index, r is the Pockels coefficient and V is the applied voltage (ChatGPT). This phenomenom is called the electro-optic effect or Pockels effect.

# %%
def get_n(n0,r,V):
    """
    :param n0: The refractive index of the crystal without an applied voltage
    :param r: The Pockels effect coefficient for our crystal
    :param V: The applied voltage by the EOM
    :return: The index of refraction produced by the applied voltage
    """
    return n0 + r*V

def EOM_phase(E_num, spacing, n0,V,r,save_as):
    
    for i, t in enumerate(np.arange(0, tmax, delta_t)):
        fig = plt.figure(figsize = [12,6])
        ax = fig.add_subplot(111, projection='3d')
        
        # Define grid for plotting
        num_points = 100
    
        x = np.linspace(0, max_coordinate(prop_dir, tmax, 0), num_points)
        y = np.linspace(0, max_coordinate(prop_dir, tmax, 1), num_points)
        z = np.linspace(0, max_coordinate(prop_dir, tmax, 2), num_points)
        x0 = np.zeros(E_num)
        # Calculate the field components
        for j in range(E_num):
            n = get_n(n0,r,V(j*spacing))
            Ex, Ey, Ez = electric_field(x, y  + j*5, z, t=t, prop_dir=prop_dir, pol_dir=[0,1,0], n=n)
            # Plot in 3D
            ax.plot(x, Ey  + j*spacing, Ez, color='b', label='Electric field')
            if x0[j] + t*c/n <= max_coordinate(prop_dir, 10, 0):
                x0[j] += t*c/n
                ax.scatter(x0[j], np.max(Ey) + j*spacing, np.max(Ez), color='g')
            else:
                x0[j] = 0
                x0[j] += t*c/n
                ax.scatter(x0[j], np.max(Ey) + j*spacing, np.max(Ez), color='g')
        # Show the propagation direction
        #ax.plot([0, prop_dir[0] * max_coordinate(prop_dir, tmax, 0)], 
                #[0, prop_dir[1] * max_coordinate(prop_dir, tmax, 1)], 
                #[0, prop_dir[2] * max_coordinate(prop_dir, tmax, 2)], color='k', linestyle='--', label='Propagation axis')
    
        ax.set_xlim(0, max_coordinate(prop_dir, 10, 0))
        ax.set_ylim(-1, spacing*E_num*max_coordinate(prop_dir, 10, 1))
        ax.set_zlim(-1, max_coordinate(prop_dir, 10, 2))

        x_start = 5
        y_limits = [-1, max_coordinate(prop_dir, 10, 1)]
        z_limits = [-1, max_coordinate(prop_dir, 10, 2)]
        vertices = [(x_start, y_limits[0], z_limits[0]),
            (x_start, y_limits[0], z_limits[1]),
            (x_start, y_limits[1], z_limits[1]),
            (x_start, y_limits[1], z_limits[0])]
        verts = [vertices]

        ax.view_init(90, 90)
        
        ax.add_collection3d(Poly3DCollection(verts, alpha=0.3, facecolor='g'))
        ax.set_box_aspect([3, 1, 1])
        # Set the labels and title
        ax.set_xlabel('X')
        ax.set_ylabel('Y')
        ax.set_zlabel('Z')
        ax.set_yticklabels([])
        ax.set_zticklabels([])
        ax.set_title('Mono-chromatic plane wave in EOM')
        #ax.legend()
        #plt.show()
        ax.figure.savefig(f'figures/{save_as}_{i:02d}.png')
        plt.close()

def V_func(y):
    return .05*y

# %%
E_num = 10
spacing = 5
n0= 1.3
func = V_func
r = 1

# Clear output directory
if os.path.exists('figures'):
    shutil.rmtree('figures')
os.makedirs('figures')
     

save_as = 'eom' # Base name for images
EOM_phase(E_num, spacing, n0,func,r, save_as) # Produce set of images for wave

# image_name = 'simple_wave'
# simple_wave(image_name) # Produce set of images for wave


### Create a GIF from the images

# Get list of input PNG files
png_files = sorted([os.path.join('figures', file) for file in os.listdir('figures') if file.endswith('.png')])

# Read PNG images and create GIF
with imageio.get_writer(image_name+'.gif', mode='I', duration=0.2) as writer:
    for png_file in png_files:
        image = imageio.imread(png_file)
        writer.append_data(image)

# %%
def waveplate(amp, w_mod, save_as, plate=5):

    for i, t in enumerate(np.arange(0, tmax, delta_t)):
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        
        # Define grid for plotting
        num_points = 50
        
        x = np.linspace(0, plate, num_points)
        y = np.linspace(0, max_coordinate(prop_dir, tmax, 1), num_points)
        z = np.linspace(0, max_coordinate(prop_dir, tmax, 2), num_points)

        
        x2 = np.linspace(plate, max_coordinate(prop_dir, tmax, 0), num_points)
        y2 = np.linspace(plate, max_coordinate(prop_dir, tmax, 1), num_points)
        z2 = np.linspace(plate, max_coordinate(prop_dir, tmax, 2), num_points)

        # Calculate the field components
        Ex, Ey, Ez = electric_field(x, y, z, t=t, prop_dir=prop_dir, pol_dir=pol_dir)
        # Calculate the field components after waveplate
        pol_dir2 = np.array([0, 1 , np.exp(1j*amp*np.sin(w_mod*t/2))])
        Ex2, Ey2, Ez2 = electric_field(x, y, z, t=t, prop_dir=prop_dir, pol_dir=pol_dir2)

        
        # Plot in 3D
        ax.plot(x, Ey, Ez, color='b', label='Electric field')
    
        # Show the propagation direction
        ax.plot([0, prop_dir[0] * max_coordinate(prop_dir, tmax, 0)], 
                [0, prop_dir[1] * max_coordinate(prop_dir, tmax, 1)], 
                [0, prop_dir[2] * max_coordinate(prop_dir, tmax, 2)], color='k', linestyle='--', label='Propagation axis')

        ax.plot(x2, Ey2.real, Ez2.real, color='b')
    
        ax.set_xlim(0, max_coordinate(prop_dir, 10, 0))
        ax.set_ylim(-1, max_coordinate(prop_dir, 10, 1))
        ax.set_zlim(-1, max_coordinate(prop_dir, 10, 2))

        x_start = plate
        x_end = max_coordinate(prop_dir, 10, 0)
        y_limits = [-1, max_coordinate(prop_dir, 10, 1)]
        z_limits = [-1, max_coordinate(prop_dir, 10, 2)]
        vertices = [
            (x_start, y_limits[0], z_limits[0]),
            (x_end, y_limits[0], z_limits[0]),
            (x_end, y_limits[1], z_limits[0]),
            (x_start, y_limits[1], z_limits[0]),
            (x_start, y_limits[0], z_limits[1]),
            (x_end, y_limits[0], z_limits[1]),
            (x_end, y_limits[1], z_limits[1]),
            (x_start, y_limits[1], z_limits[1]),]
        faces = [
        [vertices[0], vertices[1], vertices[2], vertices[3]],  # Bottom face
        [vertices[4], vertices[5], vertices[6], vertices[7]],  # Top face
        [vertices[0], vertices[1], vertices[5], vertices[4]],  # Side face 1
        [vertices[1], vertices[2], vertices[6], vertices[5]],  # Side face 2
        [vertices[2], vertices[3], vertices[7], vertices[6]],  # Side face 3
        [vertices[3], vertices[0], vertices[4], vertices[7]]   # Side face 4
    ]

        ax.view_init(15, 45)
        
        ax.add_collection3d(Poly3DCollection(faces, alpha=0.3, facecolor='g'))
        ax.set_box_aspect([3, 1, 1])
        # Set the labels and title
        ax.set_xlabel('X')
        ax.set_ylabel('Y')
        ax.set_zlabel('Z')
        ax.set_title('Mono-chromatic plane wave in 3D')
        ax.legend()
        #plt.show()
        ax.figure.savefig(f'figures/{save_as}_{i:02d}.png')
        plt.close()

# %%
## Save the collection of images produced from the function.
amp = 10
w_mod = w/10
image_name = 'eom_phase' # Base name for images

# Clear output directory
if os.path.exists('figures'):
    shutil.rmtree('figures')
os.makedirs('figures')
     

image_name = 'eom_phase' # Base name for images
waveplate(amp, w_mod, image_name) # Produce set of images for wave

# image_name = 'simple_wave'
# simple_wave(image_name) # Produce set of images for wave


### Create a GIF from the images

# Get list of input PNG files
png_files = sorted([os.path.join('figures', file) for file in os.listdir('figures') if file.endswith('.png')])

# Read PNG images and create GIF
with imageio.get_writer(image_name+'.gif', mode='I', duration=0.2) as writer:
    for png_file in png_files:
        image = imageio.imread(png_file)
        writer.append_data(image)
# Out:
# /tmp/ipykernel_15480/1993735347.py:27: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(png_file)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import jn  # Bessel function of the first kind
from sympy import symbols, summation, I, exp, sin, factorial

# Define the variables
t, A, omega, beta, Omega = symbols('t A omega beta Omega')

# Define the phase modulation equation
phase_modulation = A * exp(I * omega * t + I * beta * sin(Omega * t))

# Compute the Jacobi-Anger expansion for the phase modulation
n_terms = 100  # Number of terms in the summation
jacobi_anger_expansion = phase_modulation.rewrite(exp).expand().series(Omega, n=n_terms).removeO()

# Plot the Jacobi-Anger expansion terms
t_vals = np.linspace(0, 2*np.pi, 1000)
jacobi_anger_values = [jacobi_anger_expansion.subs({t: val, A: 1, omega: 1, beta: 1, Omega: 2}) for val in t_vals]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(t_vals, np.abs(jacobi_anger_values), label='Real Part')
plt.plot(t_vals, np.imag(jacobi_anger_values), label='Imaginary Part')
plt.xlabel('Time (t)')
plt.ylabel('Amplitude')
plt.title('Jacobi-Anger Expansion for EOM Phase Modulation')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import jn  # Bessel function of the first kind
from sympy import symbols, summation, I, exp, sin, factorial, Abs, arg

# Define the variables
t, A, omega, beta, Omega, f = symbols('t A omega beta Omega f')

# Define the phase modulation equation
phase_modulation = A * exp(I * omega * t + I * beta * sin(Omega * t))

# Compute the Jacobi-Anger expansion for the phase modulation
n_terms = 10  # Number of terms in the summation
jacobi_anger_expansion = phase_modulation.rewrite(exp).expand().series(Omega, n=n_terms).removeO()

# Compute the Fourier transform of the Jacobi-Anger expansion
fourier_transform = summation(jacobi_anger_expansion * exp(-I * 2 * np.pi * f * t), (t, 0, 2 * np.pi)).simplify()

# Plot the magnitude of the Fourier transform
f_vals = np.linspace(-5, 5, 100)  # Frequency range for plotting
fourier_values = [Abs(fourier_transform.subs({A: 1, omega: 1, beta: 1, Omega: 2, f: freq})) for freq in f_vals]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(f_vals, fourier_values, label='Magnitude (Frequency Domain)')
plt.xlabel('Frequency (f)')
plt.ylabel('Magnitude')
plt.title('Magnitude of Fourier Transform (Frequency Domain) for EOM Phase Modulation')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, I, exp, sin, fourier_transform, Abs

# Define the variables
t, A, omega, beta, Omega, f = symbols('t A omega beta Omega f')

# Define the phase modulation equation
phase_modulation = A * exp(I * omega * t + I * beta * sin(Omega * t))

# Compute the Fourier transform of the Jacobi-Anger expansion for the given phase modulation
fourier_expansion = fourier_transform(phase_modulation, t, f).simplify()

# Define a function to evaluate the magnitude of the Fourier transform numerically
def magnitude_fourier(freq_val):
    return abs(fourier_expansion.subs({A: 1, omega: 1, beta: 1, Omega: 2, f: freq_val}))

# Convert symbolic expression to a Python function for numerical evaluation
magnitude_fourier_func = np.vectorize(lambda x: magnitude_fourier(x).evalf(), otypes=float)

# Plot the magnitude of the Fourier transform
f_vals = np.linspace(-5, 5, 1000)  # Frequency range for plotting
fourier_values = magnitude_fourier_func(f_vals)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(f_vals, fourier_values, label='Magnitude (Frequency Domain)')
plt.xlabel('Frequency (f)')
plt.ylabel('Magnitude')
plt.title('Magnitude of Fourier Transform (Frequency Domain) for EOM Phase Modulation')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 19
#      16     return abs(fourier_expansion.subs({A: 1, omega: 1, beta: 1, Omega: 2, f: freq_val}))
#      18 # Convert symbolic expression to a Python function for numerical evaluation
# ---> 19 magnitude_fourier_func = np.vectorize(lambda x: magnitude_fourier(x).evalf(), otypes=float)
#      21 # Plot the magnitude of the Fourier transform
#      22 f_vals = np.linspace(-5, 5, 1000)  # Frequency range for plotting
#
# File ~/miniconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:2288, in vectorize.__init__(self, pyfunc, otypes, doc, excluded, cache, signature)
#    2286     otypes = ''.join([_nx.dtype(x).char for x in otypes])
#    2287 elif otypes is not None:
# -> 2288     raise ValueError("Invalid otype specification")
#    2289 self.otypes = otypes
#    2291 # Excluded variable support
#
# ValueError: Invalid otype specification

# %%
fourier_values
# Out:
# [Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -5.0)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.98998998998999)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.97997997997998)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.96996996996997)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.95995995995996)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.94994994994995)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.93993993993994)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.92992992992993)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.91991991991992)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.90990990990991)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.8998998998999)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.88988988988989)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.87987987987988)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.86986986986987)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.85985985985986)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.84984984984985)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.83983983983984)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.82982982982983)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.81981981981982)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.80980980980981)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.7997997997998)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.78978978978979)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.77977977977978)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.76976976976977)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.75975975975976)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.74974974974975)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.73973973973974)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.72972972972973)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.71971971971972)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.70970970970971)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.6996996996997)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.68968968968969)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.67967967967968)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.66966966966967)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.65965965965966)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.64964964964965)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.63963963963964)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.62962962962963)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.61961961961962)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.60960960960961)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.5995995995996)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.58958958958959)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.57957957957958)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.56956956956957)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.55955955955956)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.54954954954955)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.53953953953954)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.52952952952953)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.51951951951952)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.50950950950951)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.4994994994995)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.48948948948949)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.47947947947948)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.46946946946947)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.45945945945946)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.44944944944945)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.43943943943944)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.42942942942943)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.41941941941942)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.40940940940941)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.3993993993994)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.38938938938939)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.37937937937938)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.36936936936937)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.35935935935936)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.34934934934935)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.33933933933934)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.32932932932933)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.31931931931932)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.30930930930931)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.2992992992993)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.28928928928929)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.27927927927928)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.26926926926927)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.25925925925926)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.24924924924925)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.23923923923924)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.22922922922923)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.21921921921922)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.20920920920921)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.1991991991992)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.18918918918919)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.17917917917918)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.16916916916917)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.15915915915916)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.14914914914915)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.13913913913914)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.12912912912913)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.11911911911912)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.10910910910911)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.0990990990991)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.08908908908909)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.07907907907908)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.06906906906907)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.05905905905906)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.04904904904905)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.03903903903904)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.02902902902903)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.01901901901902)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -4.00900900900901)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.998998998999)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.98898898898899)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.97897897897898)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.96896896896897)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.95895895895896)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.94894894894895)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.93893893893894)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.92892892892893)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.91891891891892)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.90890890890891)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.8988988988989)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.88888888888889)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.87887887887888)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.86886886886887)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.85885885885886)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.84884884884885)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.83883883883884)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.82882882882883)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.81881881881882)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.80880880880881)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.7987987987988)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.78878878878879)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.77877877877878)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.76876876876877)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.75875875875876)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.74874874874875)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.73873873873874)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.72872872872873)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.71871871871872)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.70870870870871)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.6986986986987)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.68868868868869)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.67867867867868)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.66866866866867)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.65865865865866)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.64864864864865)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.63863863863864)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.62862862862863)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.61861861861862)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.60860860860861)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.5985985985986)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.58858858858859)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.57857857857858)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.56856856856857)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.55855855855856)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.54854854854855)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.53853853853854)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.52852852852853)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.51851851851852)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.50850850850851)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.4984984984985)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.48848848848849)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.47847847847848)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.46846846846847)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.45845845845846)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.44844844844845)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.43843843843844)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.42842842842843)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.41841841841842)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.40840840840841)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.3983983983984)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.38838838838839)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.37837837837838)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.36836836836837)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.35835835835836)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.34834834834835)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.33833833833834)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.32832832832833)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.31831831831832)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.30830830830831)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.2982982982983)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.28828828828829)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.27827827827828)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.26826826826827)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.25825825825826)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.24824824824825)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.23823823823824)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.22822822822823)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.21821821821822)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.20820820820821)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.1981981981982)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.18818818818819)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.17817817817818)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.16816816816817)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.15815815815816)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.14814814814815)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.13813813813814)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.12812812812813)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.11811811811812)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.10810810810811)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.0980980980981)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.08808808808809)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.07807807807808)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.06806806806807)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.05805805805806)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.04804804804805)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.03803803803804)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.02802802802803)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.01801801801802)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -3.00800800800801)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.997997997998)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.98798798798799)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.97797797797798)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.96796796796797)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.95795795795796)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.94794794794795)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.93793793793794)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.92792792792793)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.91791791791792)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.90790790790791)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.8978978978979)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.88788788788789)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.87787787787788)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.86786786786787)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.85785785785786)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.84784784784785)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.83783783783784)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.82782782782783)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.81781781781782)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.80780780780781)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.7977977977978)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.78778778778779)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.77777777777778)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.76776776776777)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.75775775775776)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.74774774774775)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.73773773773774)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.72772772772773)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.71771771771772)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.70770770770771)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.6976976976977)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.68768768768769)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.67767767767768)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.66766766766767)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.65765765765766)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.64764764764765)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.63763763763764)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.62762762762763)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.61761761761762)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.60760760760761)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.5975975975976)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.58758758758759)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.57757757757758)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.56756756756757)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.55755755755756)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.54754754754755)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.53753753753754)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.52752752752753)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.51751751751752)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.50750750750751)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.4974974974975)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.48748748748749)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.47747747747748)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.46746746746747)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.45745745745746)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.44744744744745)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.43743743743744)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.42742742742743)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.41741741741742)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.40740740740741)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.3973973973974)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.38738738738739)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.37737737737738)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.36736736736737)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.35735735735736)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.34734734734735)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.33733733733734)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.32732732732733)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.31731731731732)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.30730730730731)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.2972972972973)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.28728728728729)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.27727727727728)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.26726726726727)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.25725725725726)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.24724724724725)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.23723723723724)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.22722722722723)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.21721721721722)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.20720720720721)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.1971971971972)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.18718718718719)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.17717717717718)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.16716716716717)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.15715715715716)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.14714714714715)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.13713713713714)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.12712712712713)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.11711711711712)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.10710710710711)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.0970970970971)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.08708708708709)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.07707707707708)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.06706706706707)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.05705705705706)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.04704704704705)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.03703703703704)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.02702702702703)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.01701701701702)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -2.00700700700701)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.996996996997)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.98698698698699)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.97697697697698)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.96696696696697)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.95695695695696)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.94694694694695)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.93693693693694)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.92692692692693)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.91691691691692)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.90690690690691)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.8968968968969)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.88688688688689)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.87687687687688)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.86686686686687)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.85685685685686)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.84684684684685)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.83683683683684)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.82682682682683)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.81681681681682)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.80680680680681)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.7967967967968)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.78678678678679)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.77677677677678)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.76676676676677)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.75675675675676)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.74674674674675)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.73673673673674)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.72672672672673)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.71671671671672)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.70670670670671)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.6966966966967)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.68668668668669)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.67667667667668)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.66666666666667)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.65665665665666)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.64664664664665)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.63663663663664)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.62662662662663)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.61661661661662)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.60660660660661)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.5965965965966)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.58658658658659)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.57657657657658)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.56656656656657)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.55655655655656)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.54654654654655)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.53653653653654)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.52652652652653)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.51651651651652)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.50650650650651)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.4964964964965)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.48648648648649)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.47647647647648)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.46646646646647)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.45645645645646)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.44644644644645)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.43643643643644)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.42642642642643)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.41641641641642)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.40640640640641)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.3963963963964)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.38638638638639)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.37637637637638)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.36636636636637)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.35635635635636)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.34634634634635)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.33633633633634)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.32632632632633)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.31631631631632)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.30630630630631)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.2962962962963)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.28628628628629)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.27627627627628)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.26626626626627)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.25625625625626)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.24624624624625)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.23623623623624)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.22622622622623)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.21621621621622)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.20620620620621)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.1961961961962)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.18618618618619)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.17617617617618)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.16616616616617)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.15615615615616)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.14614614614615)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.13613613613614)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.12612612612613)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.11611611611612)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.10610610610611)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.0960960960961)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.08608608608609)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.07607607607608)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.06606606606607)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.05605605605606)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.04604604604605)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.03603603603604)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.02602602602603)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.01601601601602)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -1.00600600600601)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.995995995995996)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.985985985985986)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.975975975975976)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.965965965965966)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.955955955955956)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.945945945945946)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.935935935935936)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.925925925925926)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.915915915915916)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.905905905905906)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.895895895895896)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.885885885885886)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.875875875875876)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.865865865865866)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.855855855855856)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.845845845845846)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.835835835835836)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.825825825825826)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.815815815815816)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.805805805805806)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.795795795795796)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.785785785785786)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.775775775775776)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.765765765765765)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.755755755755755)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.745745745745745)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.735735735735735)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.725725725725725)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.715715715715715)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.705705705705705)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.695695695695695)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.685685685685685)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.675675675675675)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.665665665665665)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.655655655655655)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.645645645645645)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.635635635635635)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.625625625625625)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.615615615615615)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.605605605605605)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.595595595595595)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.585585585585585)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.575575575575575)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.565565565565565)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.555555555555555)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.545545545545545)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.535535535535535)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.525525525525525)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.515515515515515)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.505505505505505)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.495495495495495)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.485485485485485)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.475475475475475)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.465465465465465)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.455455455455455)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.445445445445445)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.435435435435435)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.425425425425425)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.415415415415415)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.405405405405405)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.395395395395395)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.385385385385385)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.375375375375375)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.365365365365365)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.355355355355355)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.345345345345345)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.335335335335335)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.325325325325325)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.315315315315315)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.305305305305305)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.295295295295295)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.285285285285285)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.275275275275275)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.265265265265265)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.255255255255255)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.245245245245245)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.235235235235235)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.225225225225225)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.215215215215215)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.205205205205205)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.195195195195195)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.185185185185185)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.175175175175175)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.165165165165165)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.155155155155155)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.145145145145145)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.135135135135135)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.125125125125125)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.115115115115115)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.105105105105105)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.0950950950950951)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.0850850850850851)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.075075075075075)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.065065065065065)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.055055055055055)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.045045045045045)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.035035035035035)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.025025025025025)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.015015015015015)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, -0.005005005005005)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.005005005005005)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.015015015015015)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.025025025025025)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.035035035035035)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.045045045045045)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.055055055055055)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.065065065065065)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.075075075075075)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.0850850850850851)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.0950950950950951)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.105105105105105)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.115115115115115)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.125125125125125)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.135135135135135)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.145145145145145)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.155155155155155)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.165165165165165)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.175175175175175)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.185185185185185)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.195195195195195)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.205205205205205)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.215215215215215)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.225225225225225)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.235235235235235)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.245245245245245)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.255255255255255)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.265265265265265)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.275275275275275)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.285285285285285)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.295295295295295)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.305305305305305)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.315315315315315)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.325325325325325)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.335335335335335)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.345345345345345)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.355355355355355)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.365365365365365)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.375375375375375)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.385385385385385)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.395395395395395)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.405405405405405)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.415415415415415)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.425425425425425)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.435435435435435)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.445445445445445)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.455455455455455)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.465465465465465)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.475475475475475)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.485485485485485)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.495495495495495)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.505505505505505)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.515515515515515)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.525525525525525)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.535535535535535)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.545545545545545)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.555555555555555)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.565565565565565)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.575575575575575)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.585585585585585)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.595595595595595)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.605605605605605)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.615615615615615)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.625625625625625)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.635635635635635)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.645645645645645)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.655655655655655)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.665665665665665)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.675675675675675)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.685685685685685)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.695695695695695)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.705705705705705)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.715715715715715)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.725725725725725)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.735735735735735)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.745745745745745)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.755755755755755)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.765765765765765)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.775775775775776)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.785785785785786)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.795795795795796)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.805805805805806)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.815815815815816)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.825825825825826)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.835835835835836)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.845845845845846)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.855855855855856)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.865865865865866)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.875875875875876)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.885885885885886)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.895895895895896)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.905905905905906)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.915915915915916)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.925925925925926)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.935935935935936)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.945945945945946)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.955955955955956)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.965965965965966)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.975975975975976)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.985985985985986)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 0.995995995995996)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.00600600600601)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.01601601601602)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.02602602602603)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.03603603603604)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.04604604604605)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.05605605605606)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.06606606606607)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.07607607607608)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.08608608608609)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.0960960960961)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.10610610610611)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.11611611611612)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.12612612612613)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.13613613613614)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.14614614614615)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.15615615615616)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.16616616616617)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.17617617617618)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.18618618618619)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.1961961961962)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.20620620620621)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.21621621621622)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.22622622622623)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.23623623623624)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.24624624624625)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.25625625625626)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.26626626626627)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.27627627627628)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.28628628628629)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.2962962962963)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.30630630630631)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.31631631631632)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.32632632632633)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.33633633633634)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.34634634634635)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.35635635635636)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.36636636636637)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.37637637637638)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.38638638638639)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.3963963963964)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.40640640640641)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.41641641641642)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.42642642642643)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.43643643643644)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.44644644644645)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.45645645645646)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.46646646646647)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.47647647647648)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.48648648648649)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.4964964964965)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.50650650650651)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.51651651651652)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.52652652652653)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.53653653653654)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.54654654654655)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.55655655655656)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.56656656656657)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.57657657657658)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.58658658658659)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.5965965965966)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.60660660660661)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.61661661661662)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.62662662662663)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.63663663663664)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.64664664664665)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.65665665665666)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.66666666666667)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.67667667667668)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.68668668668669)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.6966966966967)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.70670670670671)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.71671671671672)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.72672672672673)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.73673673673674)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.74674674674675)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.75675675675676)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.76676676676677)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.77677677677678)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.78678678678679)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.7967967967968)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.80680680680681)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.81681681681682)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.82682682682683)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.83683683683684)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.84684684684685)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.85685685685686)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.86686686686687)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.87687687687688)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.88688688688689)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.8968968968969)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.90690690690691)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.91691691691692)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.92692692692693)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.93693693693694)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.94694694694695)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 1.95695695695696)),
# ...
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.65765765765766)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.66766766766767)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.67767767767768)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.68768768768769)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.6976976976977)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.70770770770771)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.71771771771772)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.72772772772773)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.73773773773774)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.74774774774775)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.75775775775776)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.76776776776777)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.77777777777778)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.78778778778779)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.7977977977978)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.80780780780781)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.81781781781782)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.82782782782783)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.83783783783784)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.84784784784785)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.85785785785786)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.86786786786787)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.87787787787788)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.88788788788789)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.8978978978979)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.90790790790791)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.91791791791792)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.92792792792793)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.93793793793794)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.94794794794795)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.95795795795796)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.96796796796797)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.97797797797798)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.98798798798799)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 2.997997997998)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.00800800800801)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.01801801801802)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.02802802802803)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.03803803803804)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.04804804804805)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.05805805805806)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.06806806806807)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.07807807807808)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.08808808808809)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.0980980980981)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.10810810810811)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.11811811811812)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.12812812812813)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.13813813813814)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.14814814814815)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.15815815815816)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.16816816816817)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.17817817817818)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.18818818818819)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.1981981981982)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.20820820820821)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.21821821821822)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.22822822822823)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.23823823823824)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.24824824824825)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.25825825825826)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.26826826826827)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.27827827827828)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.28828828828829)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.2982982982983)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.30830830830831)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.31831831831832)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.32832832832833)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.33833833833834)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.34834834834835)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.35835835835836)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.36836836836837)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.37837837837838)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.38838838838839)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.3983983983984)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.40840840840841)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.41841841841842)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.42842842842843)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.43843843843844)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.44844844844845)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.45845845845846)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.46846846846847)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.47847847847848)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.48848848848849)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.4984984984985)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.50850850850851)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.51851851851852)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.52852852852853)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.53853853853854)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.54854854854855)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.55855855855856)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.56856856856857)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.57857857857858)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.58858858858859)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.5985985985986)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.60860860860861)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.61861861861862)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.62862862862863)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.63863863863864)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.64864864864865)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.65865865865866)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.66866866866867)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.67867867867868)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.68868868868869)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.6986986986987)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.70870870870871)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.71871871871872)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.72872872872873)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.73873873873874)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.74874874874875)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.75875875875876)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.76876876876877)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.77877877877878)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.78878878878879)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.7987987987988)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.80880880880881)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.81881881881882)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.82882882882883)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.83883883883884)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.84884884884885)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.85885885885886)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.86886886886887)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.87887887887888)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.88888888888889)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.8988988988989)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.90890890890891)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.91891891891892)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.92892892892893)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.93893893893894)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.94894894894895)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.95895895895896)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.96896896896897)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.97897897897898)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.98898898898899)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 3.998998998999)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.00900900900901)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.01901901901902)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.02902902902903)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.03903903903904)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.04904904904905)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.05905905905906)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.06906906906907)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.07907907907908)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.08908908908909)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.0990990990991)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.10910910910911)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.11911911911912)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.12912912912913)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.13913913913914)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.14914914914915)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.15915915915916)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.16916916916917)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.17917917917918)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.18918918918919)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.1991991991992)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.20920920920921)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.21921921921922)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.22922922922923)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.23923923923924)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.24924924924925)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.25925925925926)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.26926926926927)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.27927927927928)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.28928928928929)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.2992992992993)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.30930930930931)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.31931931931932)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.32932932932933)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.33933933933934)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.34934934934935)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.35935935935936)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.36936936936937)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.37937937937938)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.38938938938939)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.3993993993994)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.40940940940941)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.41941941941942)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.42942942942943)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.43943943943944)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.44944944944945)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.45945945945946)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.46946946946947)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.47947947947948)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.48948948948949)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.4994994994995)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.50950950950951)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.51951951951952)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.52952952952953)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.53953953953954)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.54954954954955)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.55955955955956)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.56956956956957)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.57957957957958)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.58958958958959)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.5995995995996)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.60960960960961)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.61961961961962)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.62962962962963)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.63963963963964)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.64964964964965)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.65965965965966)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.66966966966967)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.67967967967968)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.68968968968969)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.6996996996997)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.70970970970971)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.71971971971972)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.72972972972973)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.73973973973974)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.74974974974975)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.75975975975976)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.76976976976977)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.77977977977978)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.78978978978979)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.7997997997998)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.80980980980981)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.81981981981982)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.82982982982983)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.83983983983984)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.84984984984985)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.85985985985986)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.86986986986987)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.87987987987988)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.88988988988989)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.8998998998999)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.90990990990991)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.91991991991992)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.92992992992993)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.93993993993994)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.94994994994995)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.95995995995996)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.96996996996997)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.97997997997998)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 4.98998998998999)),
#  Abs(FourierTransform(exp(I*t + I*sin(2*t)), t, 5.0))]
